# %%
import pandas as pd 
import yfinance as yf
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use('seaborn-v0_8')

# %%
start = "2015-01-02"
end = "2020-12-31"
symbol = ['GE','RELIANCE.NS']

# %%
df = yf.download(symbol, start=start, end=end)
df.head()
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_22640\31656256.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start, end=end)
# [*********************100%***********************]  2 of 2 completed
# Price         Close                 High                  Low              \
# Ticker           GE RELIANCE.NS       GE RELIANCE.NS       GE RELIANCE.NS
# Date
# 2015-01-02 102.8227    189.4970 104.4640    191.7438 102.0432    189.2295
# 2015-01-05 100.9353    187.4212 102.6176    190.6418 100.6071    187.0468
# 2015-01-06  98.7607    178.9153 100.8122    186.8114  98.1863    178.0379
# 2015-01-07  98.8017    182.8098 100.0736    183.7728  98.3914    179.1078
# 2015-01-08  99.9916    180.1885 100.0326    184.6501  99.0069    179.7819
#
# Price          Open                    Volume
# Ticker           GE RELIANCE.NS            GE   RELIANCE.NS
# Date
# 2015-01-02 103.9716    190.0426  8538620.0000  7331366.0000
# 2015-01-05 102.6176    189.3792  8770735.0000 10103941.0000
# 2015-01-06 100.3609    186.1694 13304295.0000 18627980.0000
# 2015-01-07  99.3351    179.1292  9106535.0000 20720312.0000
# 2015-01-08  99.7864    184.0510  9019294.0000 19872227.0000

# %%
close = df.Close.copy()
close
# Out:
# Ticker           GE  RELIANCE.NS
# Date
# 2015-01-02 102.8227     189.4970
# 2015-01-05 100.9353     187.4212
# 2015-01-06  98.7607     178.9153
# 2015-01-07  98.8017     182.8098
# 2015-01-08  99.9916     180.1885
# ...             ...          ...
# 2020-12-23  53.0371     881.4024
# 2020-12-24  52.0115     904.2100
# 2020-12-28  51.9627     908.3589
# 2020-12-29  51.5720     902.3509
# 2020-12-30  52.3045     904.8220
#
# [1552 rows x 2 columns]

# %%
close.dropna().plot(figsize=(12,6), fontsize = 13, title='Closing Prices')
plt.legend(fontsize=13)
plt.show()

# %%
norm = close.div(close.iloc[0]).mul(1)
norm
# Out:
# Ticker         GE  RELIANCE.NS
# Date
# 2015-01-02 1.0000       1.0000
# 2015-01-05 0.9816       0.9890
# 2015-01-06 0.9605       0.9442
# 2015-01-07 0.9609       0.9647
# 2015-01-08 0.9725       0.9509
# ...           ...          ...
# 2020-12-23 0.5158       4.6513
# 2020-12-24 0.5058       4.7716
# 2020-12-28 0.5054       4.7935
# 2020-12-29 0.5016       4.7618
# 2020-12-30 0.5087       4.7749
#
# [1552 rows x 2 columns]

# %%
norm.dropna().plot(figsize=(12,6), fontsize = 13, title='Normalized Closing Prices')
plt.legend(fontsize=13)
plt.show()
