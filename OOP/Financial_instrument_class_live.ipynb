# %% [markdown]
# **Financial Instrument Class live in action: Part I**
#
# Goal: Analysing Financial Instruments efficiently

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
stock
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.start
# Out:
# '2015-01-01'

# %%
raw = yf.download('AAPL','2015-01-01','2019-12-31', multi_level_index=False).Close.to_frame()
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\4112106947.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download('AAPL','2015-01-01','2019-12-31', multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
raw
# Out:
#                 Close
# Date
# 2015-01-02  24.261049
# 2015-01-05  23.577576
# 2015-01-06  23.579790
# 2015-01-07  23.910440
# 2015-01-08  24.829124
# ...               ...
# 2019-12-23  68.589767
# 2019-12-24  68.654976
# 2019-12-26  70.017136
# 2019-12-27  69.990540
# 2019-12-30  70.405945
#
# [1257 rows x 1 columns]

# %%
raw.rename(columns={'Close':'Price'},inplace=True)
raw
# Out:
#                 Price
# Date
# 2015-01-02  24.261049
# 2015-01-05  23.577576
# 2015-01-06  23.579790
# 2015-01-07  23.910440
# 2015-01-08  24.829124
# ...               ...
# 2019-12-23  68.589767
# 2019-12-24  68.654976
# 2019-12-26  70.017136
# 2019-12-27  69.990540
# 2019-12-30  70.405945
#
# [1257 rows x 1 columns]

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self.ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self.ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\2475205002.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.ticker
# Out:
# 'AAPL'

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261049          NaN
# 2015-01-05  23.577576    -0.028576
# 2015-01-06  23.579790     0.000094
# 2015-01-07  23.910440     0.013925
# 2015-01-08  24.829124     0.037702
# ...               ...          ...
# 2019-12-23  68.589767     0.016186
# 2019-12-24  68.654976     0.000950
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990540    -0.000380
# 2019-12-30  70.405945     0.005918
#
# [1257 rows x 2 columns]

# %% [markdown]
# **The method log_returns**

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261049          NaN
# 2015-01-05  23.577576    -0.028576
# 2015-01-06  23.579790     0.000094
# 2015-01-07  23.910440     0.013925
# 2015-01-08  24.829124     0.037702
# ...               ...          ...
# 2019-12-23  68.589767     0.016186
# 2019-12-24  68.654976     0.000950
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990540    -0.000380
# 2019-12-30  70.405945     0.005918
#
# [1257 rows x 2 columns]

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self.ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self.ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\2475205002.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261049          NaN
# 2015-01-05  23.577576    -0.028576
# 2015-01-06  23.579790     0.000094
# 2015-01-07  23.910440     0.013925
# 2015-01-08  24.829124     0.037702
# ...               ...          ...
# 2019-12-23  68.589767     0.016186
# 2019-12-24  68.654976     0.000950
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990540    -0.000380
# 2019-12-30  70.405945     0.005918
#
# [1257 rows x 2 columns]

# %%
stock.log_returns()

# %% [markdown]
# **(String) Representation**

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
print(stock)
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
print(stock)
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %% [markdown]
# **The methods plot_data() and plot_returns()**

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261049          NaN
# 2015-01-05  23.577576    -0.028576
# 2015-01-06  23.579790     0.000094
# 2015-01-07  23.910440     0.013925
# 2015-01-08  24.829124     0.037702
# ...               ...          ...
# 2019-12-23  68.589767     0.016186
# 2019-12-24  68.654976     0.000950
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990540    -0.000380
# 2019-12-30  70.405945     0.005918
#
# [1257 rows x 2 columns]

# %%
stock.data.Price.plot()
plt.show()

# %%
stock.data.log_returns.plot()
plt.show()

# %%
stock.data.log_returns.hist(bins=100)
plt.show()

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self.ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self.ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\2475205002.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.plot_prices()

# %%
stock.plot_returns(kind = 'hist')

# %%
stock.plot_returns()

# %% [markdown]
# **ENCAPSULATION**

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.plot_prices()

# %%
stock.ticker
# Out:
# 'AAPL'

# %%
stock.ticker = 'GE'

# %%
stock.ticker
# Out:
# 'GE'

# %%
stock.plot_prices()

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.ticker
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 stock.ticker
#
# AttributeError: 'FinancialInstrument' object has no attribute 'ticker'

# %%
stock.
# Out:
#   Cell In[74], line 1
#     stock.
#           ^
# SyntaxError: invalid syntax

# %%
stock._ticker
# Out:
# 'AAPL'

# %% [markdown]
# **The method set_ticker()**

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)
            
    def set_ticker(self, ticker = None):
        if ticker is not None:
            self._ticker = ticker
            self.get_data()
            self.log_returns()

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\1960529313.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.plot_prices()

# %%
stock.set_ticker('GE')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\1960529313.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.plot_prices()

# %% [markdown]
# **Adding more methods and performance metrics**

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)
            
    def set_ticker(self, ticker = None):
        if ticker is None:
            self._ticker = ticker
            self.get_data()
            self.log_returns()

    def mean_return(self,freq = None):
        if freq is None:
            return self.data.log_returns.mean()
        else:
            resampled_price = self.data.Price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.mean()

    def std_returns(self, freq = None):
        if freq is None:
            return self.data.log_returns.std()
        else:
            resampled_price = self.data.Price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.std()

    def annualized_perf(self):
        mean_return = round(self.data.log_returns.mean() * 252, 3)
        risk = round(self.data.log_returns.std() * np.sqrt(252), 3)
        print("Return: {} | Risk: {}".format(mean_return, risk))

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\812026118.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.mean_return()
# Out:
# np.float64(0.0008482528260251637)

# %%
stock.mean_return("ME")
# Out:
# np.float64(0.016885357846192155)

# %%
stock.std_returns()
# Out:
# np.float64(0.015676740828669263)

# %%
stock.std_returns('ME')
# Out:
# np.float64(0.0764507406713272)

# %%
stock.annualized_perf()
# Out:
# Return: 0.214 | Risk: 0.249

# %% [markdown]
# **INHERITENCE**

# %%
class FinancialInstrument(): #Base Class
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)
            
    def set_ticker(self, ticker = None):
        if ticker is not None:
            self._ticker = ticker
            self.get_data()
            self.log_returns()

# %%
class RiskReturn(FinancialInstrument): #Child Class
    def __repr__(self):
        return "RiskReturn(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def mean_return(self,freq = None):
        if freq is None:
            return self.data.log_returns.mean()
        else:
            resampled_price = self.data.Price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.mean()

    def std_returns(self, freq = None):
        if freq is None:
            return self.data.log_returns.std()
        else:
            resampled_price = self.data.Price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.std()

    def annualized_perf(self):
        mean_return = round(self.data.log_returns.mean() * 252, 3)
        risk = round(self.data.log_returns.std() * np.sqrt(252), 3)
        print("Return: {} | Risk: {}".format(mean_return, risk))

# %%
stock = RiskReturn('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\2098961328.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.annualized_perf()
# Out:
# Return: 0.214 | Risk: 0.249

# %%
stock.set_ticker('GE')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\2098961328.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.plot_prices()

# %%
stock
# Out:
# RiskReturn(ticker = GE, start = 2015-01-01, end = 2019-12-31)

# %% [markdown]
# **Inheritence and the super() function**

# %%
class FinancialInstrument(): #Base Class
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)
            
    def set_ticker(self, ticker = None):
        if ticker is not None:
            self._ticker = ticker
            self.get_data()
            self.log_returns()

# %%
class RiskReturn(FinancialInstrument): #Child Class
    def __init__(self, ticker, start, end, freq = None):
        self.freq = freq
        super().__init__(ticker,start,end)

    def __repr__(self):
        return "RiskReturn(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def mean_return(self):
        if self.freq is None:
            return self.data.log_returns.mean()
        else:
            resampled_price = self.data.Price.resample(self.freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.mean()

    def std_returns(self):
        if self.freq is None:
            return self.data.log_returns.std()
        else:
            resampled_price = self.data.Price.resample(self.freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.std()

    def annualized_perf(self):
        mean_return = round(self.data.log_returns.mean() * 252, 3)
        risk = round(self.data.log_returns.std() * np.sqrt(252), 3)
        print("Return: {} | Risk: {}".format(mean_return, risk))

# %%
stock = RiskReturn('AAPL','2015-01-01','2019-12-31',freq='W')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\2098961328.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.freq
# Out:
# 'W'

# %%
stock._ticker
# Out:
# 'AAPL'

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261049          NaN
# 2015-01-05  23.577576    -0.028576
# 2015-01-06  23.579790     0.000094
# 2015-01-07  23.910440     0.013925
# 2015-01-08  24.829124     0.037702
# ...               ...          ...
# 2019-12-23  68.589767     0.016186
# 2019-12-24  68.654976     0.000950
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990540    -0.000380
# 2019-12-30  70.405945     0.005918
#
# [1257 rows x 2 columns]

# %%
stock.mean_return()
# Out:
# np.float64(0.004082013599569373)

# %%
stock.plot_prices()

# %%
stock.set_ticker('BTC-USD')
stock.plot_prices()
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_18920\2098961328.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed
