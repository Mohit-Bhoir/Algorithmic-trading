# %% [markdown]
# **Financial Instrument Class live in action: Part I**
#
# Goal: Analysing Financial Instruments efficiently

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
stock
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.start
# Out:
# '2015-01-01'

# %%
raw = yf.download('AAPL','2015-01-01','2019-12-31', multi_level_index=False).Close.to_frame()
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\4112106947.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download('AAPL','2015-01-01','2019-12-31', multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
raw
# Out:
#                 Close
# Date
# 2015-01-02  24.261045
# 2015-01-05  23.577574
# 2015-01-06  23.579794
# 2015-01-07  23.910431
# 2015-01-08  24.829130
# ...               ...
# 2019-12-23  68.589752
# 2019-12-24  68.654991
# 2019-12-26  70.017136
# 2019-12-27  69.990547
# 2019-12-30  70.405937
#
# [1257 rows x 1 columns]

# %%
raw.rename(columns={'Close':'Price'},inplace=True)
raw
# Out:
#                 Price
# Date
# 2015-01-02  24.261045
# 2015-01-05  23.577574
# 2015-01-06  23.579794
# 2015-01-07  23.910431
# 2015-01-08  24.829130
# ...               ...
# 2019-12-23  68.589752
# 2019-12-24  68.654991
# 2019-12-26  70.017136
# 2019-12-27  69.990547
# 2019-12-30  70.405937
#
# [1257 rows x 1 columns]

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self.ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self.ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\2475205002.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.ticker
# Out:
# 'AAPL'

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261045          NaN
# 2015-01-05  23.577574    -0.028576
# 2015-01-06  23.579794     0.000094
# 2015-01-07  23.910431     0.013925
# 2015-01-08  24.829130     0.037703
# ...               ...          ...
# 2019-12-23  68.589752     0.016186
# 2019-12-24  68.654991     0.000951
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990547    -0.000380
# 2019-12-30  70.405937     0.005917
#
# [1257 rows x 2 columns]

# %% [markdown]
# **The method log_returns**

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261045          NaN
# 2015-01-05  23.577574    -0.028576
# 2015-01-06  23.579794     0.000094
# 2015-01-07  23.910431     0.013925
# 2015-01-08  24.829130     0.037703
# ...               ...          ...
# 2019-12-23  68.589752     0.016186
# 2019-12-24  68.654991     0.000951
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990547    -0.000380
# 2019-12-30  70.405937     0.005917
#
# [1257 rows x 2 columns]

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self.ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self.ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\2475205002.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261045          NaN
# 2015-01-05  23.577574    -0.028576
# 2015-01-06  23.579794     0.000094
# 2015-01-07  23.910431     0.013925
# 2015-01-08  24.829130     0.037703
# ...               ...          ...
# 2019-12-23  68.589752     0.016186
# 2019-12-24  68.654991     0.000951
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990547    -0.000380
# 2019-12-30  70.405937     0.005917
#
# [1257 rows x 2 columns]

# %%
stock.log_returns()

# %% [markdown]
# **(String) Representation**

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
print(stock)
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
print(stock)
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %% [markdown]
# **The methods plot_data() and plot_returns()**

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.data
# Out:
#                 Price  log_returns
# Date
# 2015-01-02  24.261045          NaN
# 2015-01-05  23.577574    -0.028576
# 2015-01-06  23.579794     0.000094
# 2015-01-07  23.910431     0.013925
# 2015-01-08  24.829130     0.037703
# ...               ...          ...
# 2019-12-23  68.589752     0.016186
# 2019-12-24  68.654991     0.000951
# 2019-12-26  70.017136     0.019646
# 2019-12-27  69.990547    -0.000380
# 2019-12-30  70.405937     0.005917
#
# [1257 rows x 2 columns]

# %%
stock.data.Price.plot()
plt.show()

# %%
stock.data.log_returns.plot()
plt.show()

# %%
stock.data.log_returns.hist(bins=100)
plt.show()

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self.ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self.ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\2475205002.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.plot_prices()

# %%
stock.plot_returns(kind = 'hist')

# %%
stock.plot_returns()

# %% [markdown]
# **ENCAPSULATION**

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.plot_prices()

# %%
stock.ticker
# Out:
# 'AAPL'

# %%
stock.ticker = 'GE'

# %%
stock.ticker
# Out:
# 'GE'

# %%
stock.plot_prices()

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\796496741.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.ticker
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 stock.ticker
#
# AttributeError: 'FinancialInstrument' object has no attribute 'ticker'

# %%
stock.
# Out:
#   Cell In[74], line 1
#     stock.
#           ^
# SyntaxError: invalid syntax

# %%
stock._ticker
# Out:
# 'AAPL'

# %% [markdown]
# **The method set_ticker()**

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)
            
    def set_ticker(self, ticker = None):
        if ticker is not None:
            self._ticker = ticker
            self.get_data()
            self.log_returns()

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\1960529313.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2019-12-31)

# %%
stock.plot_prices()

# %%
stock.set_ticker('GE')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\1960529313.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.plot_prices()

# %% [markdown]
# **Adding more methods and performance metrics**

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker  # use _ticker for encapsulation
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()

    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)

    def get_data(self):
        raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
        raw.rename(columns={'Close': 'Price'}, inplace=True)
        self.data = raw

    def log_returns(self):
        self.data['log_returns'] = np.log(self.data.Price / self.data.Price.shift(1))

    def plot_prices(self):
        self.data.Price.plot(figsize=(12, 8))
        plt.title('Price Chart: {}'.format(self._ticker), fontsize=15)

    def plot_returns(self, kind='ts'):
        if kind == 'ts':
            self.data.log_returns.plot(figsize=(12, 8))
            plt.title("Returns: {}".format(self._ticker), fontsize=15)
        elif kind == 'hist':
            self.data.log_returns.hist(figsize=(12, 8), bins=int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize=15)
            
    def set_ticker(self, ticker = None):
        if ticker is None:
            self._ticker = ticker
            self.get_data()
            self.log_returns()

    def mean_return(self,freq = None):
        if freq is None:
            return self.data.log_returns.mean()
        else:
            resampled_price = self.data.Price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.mean()

    def std_returns(self, freq = None):
        if freq is None:
            return self.data.log_returns.std()
        else:
            resampled_price = self.data.Price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.std()

    def annualized_perf(self):
        mean_return = round(self.data.log_returns.mean() * 252, 3)
        risk = round(self.data.log_returns.std() * np.sqrt(252), 3)
        print("Return: {} | Risk: {}".format(mean_return, risk))

# %%
stock = FinancialInstrument('AAPL','2015-01-01','2019-12-31')
# Out:
# C:\Users\Mohit\AppData\Local\Temp\ipykernel_13872\812026118.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index=False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock.mean_return()
# Out:
# np.float64(0.0008482528649364206)

# %%
stock.mean_return("ME")
# Out:
# np.float64(0.01688535103572996)

# %%
stock.std_returns()
# Out:
# np.float64(0.015676726816833877)

# %%
stock.std_returns('ME')
# Out:
# np.float64(0.07645071273120105)

# %%
stock.annualized_perf()
# Out:
# Return: 0.214 | Risk: 0.249

# %% [markdown]
# **INHERITENCE**
